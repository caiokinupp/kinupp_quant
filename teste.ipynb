# %%
from quant_lib import *
import pandas as pd
import numpy as np

# %%
df_stock = download_data("VALE3.SA", "2014-01-01", "2024-01-01")
df_stock.Close.plot()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <Axes: xlabel='Date'>

# %%
print(rolling_z_score(df_stock.Close,252)[-1])
rolling_z_score(df_stock.Close,len(df_stock.Close)-1).plot()
# Out:
# 0.3132621926545692
# <Axes: xlabel='Date'>

# %%
((df_stock.Close - df_stock.Close.mean())/np.std(df_stock.Close)).plot()
# Out:
# <Axes: xlabel='Date'>
